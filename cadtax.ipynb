# %%
# File cadtax.py
import pandas as pd
from pandas import DataFrame


class cadtax:
    def bc(n):
        return n*0.12
    def alb(n):
        return n*0.05
    def sas(n):
        return n*0.11  
    def man(n):
        return n*0.13
    def ont(n):
        return n*0.13
    def que(n):
        return n*0.14975
    def nb(n):
        return n*0.15
    def pei(n):
        return n*0.15
    def ns(n):
        return n*0.15
    def nal(n):
        return n*0.15
    def yuk(n):
        return n*0.05
    def nwt(n):
        return n*0.05
    def nun(n):
        return n*0.05
    
    def provrate(prov):
        if prov == "bc"
            print("The tax rates for", prov, "are 7% PST and 5% GST for a total of 12%.")
        if prov == "sas"
            print("The tax rates for", prov, "are 6% PST and 5% GST for a total of 11%.") 
        if prov == "que"
            print("The tax rates for", prov, "are 9.975% QST and 5% GST for a total of 14.975%.")
        if prov == "man" or prov == "ont"
            print("The tax rates for", prov, "are 8% PST and 5% GST for a total of 13%.") 
        if prov == "nb" or prov == "pei" or prov == "ns" or prov == "nal"
            print("The tax rates for", prov, "are 10% PST and 5% GST for a total of 15%.") 
        if prov == "alb" or prov == "yuk" or prov == "nwt" or prov == "nun"
            print("The tax rates for", prov, "are 0% PST and 5% GST for a total of 5%.")
            
    def rates():
        
        ind = ["Alberta", "British Columbia", "Manitoba", "New-Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut","Ontario", "Prince Edward Island(PEI)", "Quebec", "Saskatchewan", "Yukon"]-
        
        df = pd.DataFrame({"Provincial rate(PST)" : [str(0) + "%", str(7) + "%",str(8) + "%",str(10) + "%",str(10) + "%",str(0) + "%",str(10) + "%",str(0) + "%",str(8) + "%",str(10) + "%",str(9.975) + "%",str(6) + "%",str(0) + "%"],
                  "Canada rate(GST)" : [str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%"],
                  "Total" : [str(5) + "%",str(12)+ "%",str(13)+ "%",str(15)+ "%",str(15)+ "%",str(5)+ "%",str(15)+ "%",str(5)+ "%",str(13)+ "%",str(15)+ "%",str(14.975)+ "%",str(11)+ "%",str(5) + "%"]}, index = ind)
        return df
    
    def ratesgraph():

# %%
import pandas as pd
from pandas import DataFrame

ind = ["Alberta", "British Columbia", "Manitoba", "New-Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut","Ontario", "Prince Edward Island(PEI)", "Quebec", "Saskatchewan", "Yukon"]

df = pd.DataFrame({"Provincial rate(PST)" : [str(0) + "%", str(7) + "%",str(8) + "%",str(10) + "%",str(10) + "%",str(0) + "%",str(10) + "%",str(0) + "%",str(8) + "%",str(10) + "%",str(9.975) + "%",str(6) + "%",str(0) + "%"],
                  "Canada rate(GST)" : [str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%"],
                  "Total" : [str(5) + "%",str(12)+ "%",str(13)+ "%",str(15)+ "%",str(15)+ "%",str(5)+ "%",str(15)+ "%",str(5)+ "%",str(13)+ "%",str(15)+ "%",str(14.975)+ "%",str(11)+ "%",str(5) + "%"]}, index = ind)

df
# Out:
#                           Provincial rate(PST) Canada rate(GST)    Total
# Alberta                                     0%               5%       5%
# British Columbia                            7%               5%      12%
# Manitoba                                    8%               5%      13%
# New-Brunswick                              10%               5%      15%
# Newfoundland and Labrador                  10%               5%      15%
# Northwest Territories                       0%               5%       5%
# Nova Scotia                                10%               5%      15%
# Nunavut                                     0%               5%       5%
# Ontario                                     8%               5%      13%
# Prince Edward Island(PEI)                  10%               5%      15%
# Quebec                                  9.975%               5%  14.975%
# Saskatchewan                                6%               5%      11%
# ...

# %%
class objectprice():
    def __init__(self, name, price, prov):
        self.name = name
        self.price = price
        self.prov = prov
        
    def getprice(self):
        return calctax.tax(self)
        
               
class calctax():
    def __init__(self, name, price, prov):
        ObjectPrice.__init__(self, name, price, prov)
    
    def tax(self):
    
        if self.prov == 'bc':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.12 + self.price))
        if self.prov == 'alb':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.05 + self.price))
        if self.prov == 'sas':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.11 + self.price))
        if self.prov == 'man':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.13 + self.price))
        if self.prov == 'ont':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.13 + self.price))
        if self.prov == 'que':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.14975 + self.price))
        if self.prov == 'nb':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.15 + self.price))
        if self.prov == 'pei':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.15 + self.price))
        if self.prov == 'ns':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.15 + self.price))
        if self.prov == 'nal':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.15 + self.price))
        if self.prov == 'yuk':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.05 + self.price))
        if self.prov == 'nwt':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.05 + self.price))
        if self.prov == 'nun':
            return print("the total price is for the item " + self.name + " is: " +"$" + str(self.price*0.05 + self.price))
        
        
a = objectprice('Shoes', 100, 'nun')
a.getprice()
# Out:
# the total price is for the item Shoes is: $105.0

# %%
import pandas as pd
from pandas import DataFrame

def taxrates():
    ind = ["Alberta", "British Columbia", "Manitoba", "New-Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut","Ontario", "Prince Edward Island(PEI)", "Quebec", "Saskatchewan", "Yukon"]

    df = pd.DataFrame({"Provincial rate(PST)" : [str(0) + "%", str(7) + "%",str(8) + "%",str(10) + "%",str(10) + "%",str(0) + "%",str(10) + "%",str(0) + "%",str(8) + "%",str(10) + "%",str(9.975) + "%",str(6) + "%",str(0) + "%"],
                  "Canada rate(GST)" : [str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%"],
                  "Total" : [str(5) + "%",str(12)+ "%",str(13)+ "%",str(15)+ "%",str(15)+ "%",str(5)+ "%",str(15)+ "%",str(5)+ "%",str(13)+ "%",str(15)+ "%",str(14.975)+ "%",str(11)+ "%",str(5) + "%"]}, index = ind)
    return df

taxrates()
# Out:
#                           Provincial rate(PST) Canada rate(GST)    Total
# Alberta                                     0%               5%       5%
# British Columbia                            7%               5%      12%
# Manitoba                                    8%               5%      13%
# New-Brunswick                              10%               5%      15%
# Newfoundland and Labrador                  10%               5%      15%
# Northwest Territories                       0%               5%       5%
# Nova Scotia                                10%               5%      15%
# Nunavut                                     0%               5%       5%
# Ontario                                     8%               5%      13%
# Prince Edward Island(PEI)                  10%               5%      15%
# Quebec                                  9.975%               5%  14.975%
# Saskatchewan                                6%               5%      11%
# ...
