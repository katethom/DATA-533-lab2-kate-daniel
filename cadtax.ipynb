# %%
# File cadtax.py
import pandas as pd
from pandas import DataFrame


class cadtax:
    def bc(n):
        return n*0.12
    def alb(n):
        return n*0.05
    def sas(n):
        return n*0.11  
    def man(n):
        return n*0.13
    def ont(n):
        return n*0.13
    def que(n):
        return n*0.14975
    def nb(n):
        return n*0.15
    def pei(n):
        return n*0.15
    def ns(n):
        return n*0.15
    def nal(n):
        return n*0.15
    def yuk(n):
        return n*0.05
    def nwt(n):
        return n*0.05
    def nun(n):
        return n*0.05
    
    def provrate(prov):
        if prov == "bc"
            print("The tax rates for", prov, "are 7% PST and 5% GST for a total of 12%.")
        if prov == "sas"
            print("The tax rates for", prov, "are 6% PST and 5% GST for a total of 11%.") 
        if prov == "que"
            print("The tax rates for", prov, "are 9.975% QST and 5% GST for a total of 14.975%.")
        if prov == "man" or prov == "ont"
            print("The tax rates for", prov, "are 8% PST and 5% GST for a total of 13%.") 
        if prov == "nb" or prov == "pei" or prov == "ns" or prov == "nal"
            print("The tax rates for", prov, "are 10% PST and 5% GST for a total of 15%.") 
        if prov == "alb" or prov == "yuk" or prov == "nwt" or prov == "nun"
            print("The tax rates for", prov, "are 0% PST and 5% GST for a total of 5%.")
            
    def rates():
        
        ind = ["Alberta", "British Columbia", "Manitoba", "New-Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut","Ontario", "Prince Edward Island(PEI)", "Quebec", "Saskatchewan", "Yukon"]-
        
        df = pd.DataFrame({"Provincial rate(PST)" : [str(0) + "%", str(7) + "%",str(8) + "%",str(10) + "%",str(10) + "%",str(0) + "%",str(10) + "%",str(0) + "%",str(8) + "%",str(10) + "%",str(9.975) + "%",str(6) + "%",str(0) + "%"],
                  "Canada rate(GST)" : [str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%"],
                  "Total" : [str(5) + "%",str(12)+ "%",str(13)+ "%",str(15)+ "%",str(15)+ "%",str(5)+ "%",str(15)+ "%",str(5)+ "%",str(13)+ "%",str(15)+ "%",str(14.975)+ "%",str(11)+ "%",str(5) + "%"]}, index = ind)
        return df
    
    def ratesgraph():

# %%
import pandas as pd
from pandas import DataFrame

ind = ["Alberta", "British Columbia", "Manitoba", "New-Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut","Ontario", "Prince Edward Island(PEI)", "Quebec", "Saskatchewan", "Yukon"]

df = pd.DataFrame({"Provincial rate(PST)" : [str(0) + "%", str(7) + "%",str(8) + "%",str(10) + "%",str(10) + "%",str(0) + "%",str(10) + "%",str(0) + "%",str(8) + "%",str(10) + "%",str(9.975) + "%",str(6) + "%",str(0) + "%"],
                  "Canada rate(GST)" : [str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%",str(5)+ "%"],
                  "Total" : [str(5) + "%",str(12)+ "%",str(13)+ "%",str(15)+ "%",str(15)+ "%",str(5)+ "%",str(15)+ "%",str(5)+ "%",str(13)+ "%",str(15)+ "%",str(14.975)+ "%",str(11)+ "%",str(5) + "%"]}, index = ind)

df
# Out:
#                           Provincial rate(PST) Canada rate(GST)    Total
# Alberta                                     0%               5%       5%
# British Columbia                            7%               5%      12%
# Manitoba                                    8%               5%      13%
# New-Brunswick                              10%               5%      15%
# Newfoundland and Labrador                  10%               5%      15%
# Northwest Territories                       0%               5%       5%
# Nova Scotia                                10%               5%      15%
# Nunavut                                     0%               5%       5%
# Ontario                                     8%               5%      13%
# Prince Edward Island(PEI)                  10%               5%      15%
# Quebec                                  9.975%               5%  14.975%
# Saskatchewan                                6%               5%      11%
# Yukon                                       0%               5%       5%

# %%
def ProvTax():
# Out:
#   File "<ipython-input-1-f86a6101f9cf>", line 1
#     def provtax():
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
class Calculator():
    def __init__(self,name,price,prov):
        self.name = name
        self.price = price
        self.prov = prov
    
    def provTax(self):
        if self.prov == 'bc':
            return 0.12
        if self.prov == 'alb':
            return 0.05
        if self.prov == 'sas':
            return 0.11  
        if self.prov == 'man':
            return n*0.13
        if self.prov == 'ont':
            return 0.13
        if self.prov == 'que':
            return 0.14975
        if self.prov == 'nb':
            return 0.15
        if self.prov == 'pei':
            return 0.15
        if self.prov == 'ns':
            return 0.15
        if self.prov == 'nal':
            return 0.15
        if self.prov == 'yuk':
            return 0.05
        if self.prov == 'nwt':
            return 0.05
        if self.prov == 'nun':
            return 0.05

    def calcTax(self):
        rate = provTax()
        total = int(self.price)*int(rate) + int(self.price)
        print("The total price for the item", self.name, "is", total, "in the province of", self.prov)
        
        
a = Calculator('Shoes', 100, 'bc')
a.calcTax()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6491485fa95c> in <module>()
#      40
#      41 a = Calculator('Shoes', 100, 'bc')
# ---> 42 a.calcTax()
#
# <ipython-input-17-6491485fa95c> in calcTax(self)
#      34
#      35     def calcTax(self):
# ---> 36         rate = provTax()
#      37         total = int(self.price)*int(rate) + int(self.price)
#      38         print("The total price for the item", self.name, "is", total, "in the province of", self.prov)
#
# NameError: name 'provTax' is not defined
